# %% [markdown]
# # Test Unstructured Amazon Bedrock Knowledge Base
#
# This notebook tests the unstructured Amazon Bedrock Knowledge Base created in the previous notebook using the `RetrieveAndGenerate` API.

# %% [markdown]
# ## Setup and Prerequisites
#
# ### Prerequisites
# * Completed `1.1-prerequisites-unstructured-kb.ipynb` notebook
# * Unstructured Knowledge Base successfully created and ingested
#
# Let's start by importing the required libraries and loading the Knowledge Base configuration:

# %% [markdown]
# Import required libraries for AWS service interaction and testing the Knowledge Base retrieval capabilities.

# %%
import os
import json
import time
import boto3
import logging
from datetime import datetime

# %% [markdown]
# Initialize AWS service clients for Bedrock Agent Runtime to query the Knowledge Base and retrieve account information.

# %%
# Initialize AWS clients

session = boto3.session.Session()
sts_client = boto3.client('sts')
region = session.region_name
account_id = sts_client.get_caller_identity()["Account"]

bedrock_agent_runtime_client = boto3.client("bedrock-agent-runtime")

print(f"AWS Region: {region}")
print(f"AWS Account ID: {account_id}")
# Out:
# AWS Region: us-west-2
# AWS Account ID: 298894475115

# %% [markdown]
# ## Load Unstructured Knowledge Base Configuration
#
# Load the Knowledge Base ID and configuration from the prerequisite notebook.

# %%
# Load stored variables from prerequisite notebook
# %store -r unstructured_kb_id
# %store -r kb_region
# %store -r data_bucket_name

# Validate that variables were loaded
if 'unstructured_kb_id' not in locals():
    raise ValueError("Unstructured KB ID not found. Please run 1.1-prerequisites-unstructured-kb.ipynb first.")

print("Unstructured Knowledge Base Configuration:")
print("=" * 50)
print(f"KB ID: {unstructured_kb_id}")
print(f"Region: {kb_region}")
print(f"S3 Bucket: {data_bucket_name}")
print("=" * 50)
# Out:
# Unstructured Knowledge Base Configuration:
# ==================================================
# KB ID: V68P9X9IO2
# Region: us-west-2
# S3 Bucket: product-reviews-unstructured-onamusic-bucket
# ==================================================

# %% [markdown]
# ## Setup Retrieval Configuration
#
# Set up the foundation model and retrieval parameters.

# %%
# Test configuration
foundation_model = "anthropic.claude-haiku-4-5-20251001-v1:0"

# For metadata filtering, use Claude Haiku 4.5 (now supported for implicit filtering)
# AWS Documentation: https://docs.aws.amazon.com/bedrock/latest/userguide/kb-test-config.html#kb-test-config-implicit-filter
metadata_filter_model = "anthropic.claude-haiku-4-5-20251001-v1:0"
max_results = 5

# Construct the full ARN for the global inference profile
# Global inference profiles require the full ARN format for Knowledge Base retrieval
foundation_model_arn = f"arn:aws:bedrock:{region}:{account_id}:inference-profile/global.{foundation_model}"

# Construct the foundation model ARN for metadata filtering (also using global inference profile)
metadata_filter_model_arn = f"arn:aws:bedrock:{kb_region}:{account_id}:inference-profile/global.{metadata_filter_model}"

print(f"Using foundation model: {foundation_model}")
print(f"Foundation model ARN: {foundation_model_arn}")
print(f"Metadata filter model: {metadata_filter_model}")
print(f"Metadata filter model ARN: {metadata_filter_model_arn}")
print(f"Max results per query: {max_results}")
print("\n📖 Documentation: https://docs.aws.amazon.com/bedrock/latest/userguide/kb-test-config.html#kb-test-config-implicit-filter")
# Out:
# Using foundation model: anthropic.claude-haiku-4-5-20251001-v1:0
# Foundation model ARN: arn:aws:bedrock:us-west-2:298894475115:inference-profile/global.anthropic.claude-haiku-4-5-20251001-v1:0
# Metadata filter model: anthropic.claude-haiku-4-5-20251001-v1:0
# Metadata filter model ARN: arn:aws:bedrock:us-west-2:298894475115:inference-profile/global.anthropic.claude-haiku-4-5-20251001-v1:0
# Max results per query: 5
#
# 📖 Documentation: https://docs.aws.amazon.com/bedrock/latest/userguide/kb-test-config.html#kb-test-config-implicit-filter

# %% [markdown]
# ## Helper Functions
#
# Define helper functions to format and display results from the Knowledge Base APIs.

# %%
def run_unstructured_kb_query(query, use_metadata_filtering=False):
    """
    Test a query against the retrieve_and_generate API with optional metadata filtering

    Args:
        query (str): The query to test
        use_metadata_filtering (bool): Whether to enable autogenerated metadata filtering
    """

    try:
        # Base retrieval configuration
        retrieval_config = {
            "vectorSearchConfiguration": {
                "numberOfResults": max_results
            }
        }

        # Add autogenerated metadata filtering if requested
        if use_metadata_filtering:
            retrieval_config["vectorSearchConfiguration"]["implicitFilterConfiguration"] = {
                "metadataAttributes": [
                    {
                        "key": "product_type",
                        "type": "STRING",
                        "description": "The type of product being reviewed. Possible values include: 'cookbook', 'kitchenware', 'furniture', 'speaker', 'educational toy', 'board game', 'shirt', 'self-help'"
                    },
                    {
                        "key": "rating",
                        "type": "NUMBER",
                        "description": "The rating given by the customer, ranging from 1 to 5 stars"
                    },
                    {
                        "key": "created_at",
                        "type": "STRING",
                        "description": "The date when the review was created in YYYY-MM-DD format"
                    },
                    {
                        "key": "product_id",
                        "type": "STRING",
                        "description": "The unique identifier of the product being reviewed"
                    },
                    {
                        "key": "customer_id",
                        "type": "STRING",
                        "description": "The unique identifier of the customer who wrote the review"
                    }
                ],
                # Use the pre-configured foundation model ARN for metadata filtering
                "modelArn": metadata_filter_model_arn
            }

        # Display whether metadata filtering was used
        filter_status = "WITH METADATA FILTERING" if use_metadata_filtering else "WITHOUT METADATA FILTERING"
        print(f"\n{'='*20} RETRIEVE AND GENERATE API {filter_status} {'='*20}")

        # Call retrieve_and_generate API - use the global inference profile ARN for main generation
        rag_response = bedrock_agent_runtime_client.retrieve_and_generate(
            input={'text': query},
            retrieveAndGenerateConfiguration={
                'type': 'KNOWLEDGE_BASE',
                'knowledgeBaseConfiguration': {
                    'knowledgeBaseId': unstructured_kb_id,
                    "modelArn": foundation_model_arn,  # Use the constructed inference profile ARN
                    "retrievalConfiguration": retrieval_config,
                    "generationConfiguration": {
                        "promptTemplate": {
                            "textPromptTemplate": "You are a customer feedback analyst. Objectively summarize customer reviews including both positive and negative feedback.\n\n$search_results$\n$output_format_instructions$\nAnswer: $query$"
                        }
                    }
                }
            }
        )

        # Display results with enhanced metadata information
        display_rag_results_with_metadata(rag_response, query, use_metadata_filtering)

    except Exception as e:
        print(f"Error in retrieve_and_generate API: {e}")



def display_rag_results_with_metadata(response, query, metadata_filtering_used=False):
    """
    Display results from the retrieve_and_generate API with enhanced metadata information
    
    Args:
        response: The API response
        query (str): The original query
        metadata_filtering_used (bool): Whether metadata filtering was enabled
    """
    print(f"\nQUERY: {query}")
    print("-" * 40)
    
    if 'output' in response:
        print("GENERATED RESPONSE:")
        print("-" * 40)
        print(response['output']['text'])
        
        if 'citations' in response:
            citations = response['citations']
            print(f"\nCITATIONS ({len(citations)} found):")
            print("-" * 40)
            
            for i, citation in enumerate(citations, 1):
                print(f"\nCitation {i}:")
                
                if 'retrievedReferences' in citation:
                    refs = citation['retrievedReferences']
                    for j, ref in enumerate(refs, 1):
                        print(f"  Reference {j}:")
                        
                        # Display content
                        content = ref.get('content', {})
                        if 'text' in content:
                            text = content['text']
                            print(f"    Content: {text[:200]}..." if len(text) > 200 else f"    Content: {text}")
                        
                        # Display enhanced metadata information
                        if 'metadata' in ref:
                            metadata = ref['metadata']
                            print(f"    Metadata:")
                            for key, value in metadata.items():
                                print(f"      {key}: {value}")
                        
                        # Display source location
                        if 'location' in ref:
                            location = ref['location']
                            if 's3Location' in location:
                                s3_info = location['s3Location']
                                print(f"    Source: {s3_info.get('uri', 'N/A')}")
                        
                        # Display score if available
                        if 'score' in ref:
                            print(f"    Relevance Score: {ref['score']}")
        
    else:
        print("No response generated")

# %% [markdown]
# ## Test Queries for Unstructured Customer Review Data
#
# Now let's test various types of qualitative queries that work well with our unstructured customer review data. We'll look at both regular queries and queries with autogenerated metadata filtering.
#
# ### Available Metadata Attributes:
# - **product_type**: cookbook, kitchenware, furniture, speaker, educational toy, board game, shirt, self-help
# - **rating**: 1-5 stars
# - **created_at**: Review date
# - **review_id**: Unique review identifier
# - **product_id**: Unique product identifier

# %% [markdown]
# ### Query 1

# %%
# Without metadata filtering
run_unstructured_kb_query("What specific problems or benefits do customers describe when reviewing product_890?")
# Out:
# ==================== RETRIEVE AND GENERATE API WITHOUT METADATA FILTERING ====================
#
# QUERY: What specific problems or benefits do customers describe when reviewing product_890?
# ----------------------------------------
# GENERATED RESPONSE:
# ----------------------------------------
# Based on the customer reviews available, I cannot identify which specific products correspond to "product_890" in the search results provided. The reviews discuss various furniture items (an armchair, sectional sofa), a learning toy, a speaker, and kitchenware, but none are explicitly labeled with a product number or identified as product_890.
#
# To provide accurate information about the specific problems and benefits customers describe for product_890, I would need search results that clearly identify which product is being referenced by that product ID.
#
# CITATIONS (1 found):
# ----------------------------------------
#
# Citation 1:
#   Reference 1:
#     Content: I absolutely love my new armchair from this brand - the fabric is a beautiful heather gray that matches my living room perfectly and the cushioning is incredibly comfortable. The chair arrived well-pa...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_2325
#       review_id: review_2325
#       product_type: furniture
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_561
#       rating: 4.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2022-07-23
#       review_text: I absolutely love my new armchair from this brand - the fabric is a beautiful heather gray that matches my living room perfectly and the cushioning is incredibly comfortable. The chair arrived well-packaged and was easy to assemble, though it did take me about 30 minutes to put together all the pieces. While the price was a bit higher than I initially wanted to spend, the quality seems excellent and I can tell this piece will last me for years. My only minor complaint is that the seat cushion could be a tiny bit firmer, but overall I'm really happy with my purchase and would definitely recommend it to others looking for a stylish and sturdy armchair.
#       customer_id: customer_998
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ADYxD5JwB12yEb9RmXg03
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_2325
#   Reference 2:
#     Content: This is a good quality speaker that I would recommend to others.
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_9681
#       review_id: review_9681
#       product_type: speaker
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_184
#       rating: 4.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-09-21
#       review_text: This is a good quality speaker that I would recommend to others.
#       customer_id: customer_4577
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3AWaJD5JwBGTaWacUHYKt_
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_9681
#   Reference 3:
#     Content: My kids absolutely love this learning toy - it's been such a fantastic way to keep them engaged while teaching important skills! The interactive design makes complex concepts really fun and easy to un...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_6130
#       review_id: review_6130
#       product_type: educational toy
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_763
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-12-10
#       review_text: My kids absolutely love this learning toy - it's been such a fantastic way to keep them engaged while teaching important skills! The interactive design makes complex concepts really fun and easy to understand, and I've noticed my 7-year-old's problem-solving abilities improving dramatically since we started using it. The build quality is excellent, the educational content is age-appropriate and challenging without being frustrating, and it's definitely worth every penny for parents looking to make learning enjoyable for their children.
#       customer_id: customer_3968
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3AWqJD5JwBGTaWacUHYqsS
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_6130
#   Reference 4:
#     Content: I absolutely love my new sectional sofa from this brand - the quality is outstanding and it fits perfectly in my living room! The fabric is incredibly soft and durable, and the cushions maintain their...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_1262
#       review_id: review_1262
#       product_type: furniture
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_561
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2022-03-29
#       review_text: I absolutely love my new sectional sofa from this brand - the quality is outstanding and it fits perfectly in my living room! The fabric is incredibly soft and durable, and the cushions maintain their shape even after weeks of daily use. Assembly was surprisingly easy, and the modern design has received tons of compliments from my friends and family. This is hands down the best furniture purchase I've made in years, and I would recommend it to anyone looking for a stylish and comfortable seating solution.
#       customer_id: customer_2108
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3AVKJD5JwBGTaWacUHXqtM
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_1262
#   Reference 5:
#     Content: The kitchenware works but has several issues. I wouldn't recommend it.
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_9824
#       review_id: review_9824
#       product_type: kitchenware
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_890
#       rating: 2.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2020-07-24
#       review_text: The kitchenware works but has several issues. I wouldn't recommend it.
#       customer_id: customer_915
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3AYKJD5JwBGTaWacUHZatH
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_9824

# %% [markdown]
# As shown above, when metadata filtering is not applied, the Knowledge Base may retrieve reviews for products other than `product_890` if their content is semantically similar. This happens because the retrieval process relies on semantic similarity rather than exact product ID matching.
#
# Next, we'll look at how enabling **autogenerated metadata filtering** restricts the results to only those reviews that specifically reference `product_890` in their metadata, ensuring more precise answers and citations.

# %%
# With metadata filtering
run_unstructured_kb_query("What specific problems or benefits do customers describe when reviewing product_890?", use_metadata_filtering=True)
# Out:
# ==================== RETRIEVE AND GENERATE API WITH METADATA FILTERING ====================
#
# QUERY: What specific problems or benefits do customers describe when reviewing product_890?
# ----------------------------------------
# GENERATED RESPONSE:
# ----------------------------------------
# Problems: Customers reported significant durability and quality issues with this mixing bowl set. The plastic material warped when exposed to hot ingredients, and bowls cracked or broke during normal use. Handles were described as flimsy and broke off after just a couple of uses. The smallest bowl in the set felt structurally weak. Additionally, the non-slip grip on the bottom was less effective than expected. Overall, customers felt the product quality was poor relative to the price paid. Benefits: The set has a polished stainless steel appearance that looks nice, and the bowls nest together efficiently for convenient storage. The bowls can handle basic mixing tasks adequately.
#
# CITATIONS (2 found):
# ----------------------------------------
#
# Citation 1:
#   Reference 1:
#     Content: I am absolutely furious with this terrible mixing bowl set! The cheap plastic warped the first time I tried to use it with hot ingredients, and now it's completely misshapen and unusable. The handles ...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_8137
#       review_id: review_8137
#       product_type: kitchenware
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_890
#       rating: 1.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-02-05
#       review_text: I am absolutely furious with this terrible mixing bowl set! The cheap plastic warped the first time I tried to use it with hot ingredients, and now it's completely misshapen and unusable. The handles are flimsy, the material feels like it would crack if you looked at it wrong, and for the price I paid, I expected something that would actually last more than one use in my kitchen. Save your money and avoid this garbage kitchenware - I've had better luck with dollar store products.
#       customer_id: customer_2937
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3AS6JD5JwBGTaWacUHWav0
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_8137
#   Reference 2:
#     Content: I'm absolutely furious with this cheap, poorly designed mixing bowl set. The handles broke off after just two uses, and when I tried to mix some cake batter, the entire bowl cracked right down the mid...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_252
#       review_id: review_252
#       product_type: kitchenware
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_890
#       rating: 1.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2022-06-11
#       review_text: I'm absolutely furious with this cheap, poorly designed mixing bowl set. The handles broke off after just two uses, and when I tried to mix some cake batter, the entire bowl cracked right down the middle, spilling ingredients all over my kitchen counter. Save your money and avoid this terrible product - the quality is embarrassingly bad, and I've had better luck with dollar store kitchenware than this overpriced garbage.
#       customer_id: customer_2700
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ASqJD5JwBGTaWacUHWatI
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_252
#   Reference 3:
#     Content: I bought this mixing bowl set hoping it would be a game-changer in my kitchen, but it's just okay. The stainless steel looks nice and they nest well for storage, but the smallest bowl feels a bit flim...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_5643
#       review_id: review_5643
#       product_type: kitchenware
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_890
#       rating: 3.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-04-22
#       review_text: I bought this mixing bowl set hoping it would be a game-changer in my kitchen, but it's just okay. The stainless steel looks nice and they nest well for storage, but the smallest bowl feels a bit flimsy and the grip on the bottom isn't as non-slip as I expected. They get the job done for basic mixing tasks, but I'm not completely impressed - I might look for a more robust set next time.
#       customer_id: customer_2881
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ADIxD5JwB12yEb9RmXg0d
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_5643
#   Reference 4:
#     Content: The kitchenware works but has several issues. I wouldn't recommend it.
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_9824
#       review_id: review_9824
#       product_type: kitchenware
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_890
#       rating: 2.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2020-07-24
#       review_text: The kitchenware works but has several issues. I wouldn't recommend it.
#       customer_id: customer_915
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3AYKJD5JwBGTaWacUHZatH
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_9824
#
# Citation 2:
#   Reference 1:
#     Content: I bought this mixing bowl set hoping it would be a game-changer in my kitchen, but it's just okay. The stainless steel looks nice and they nest well for storage, but the smallest bowl feels a bit flim...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_5643
#       review_id: review_5643
#       product_type: kitchenware
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_890
#       rating: 3.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-04-22
#       review_text: I bought this mixing bowl set hoping it would be a game-changer in my kitchen, but it's just okay. The stainless steel looks nice and they nest well for storage, but the smallest bowl feels a bit flimsy and the grip on the bottom isn't as non-slip as I expected. They get the job done for basic mixing tasks, but I'm not completely impressed - I might look for a more robust set next time.
#       customer_id: customer_2881
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ADIxD5JwB12yEb9RmXg0d
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_5643

# %% [markdown]
# ### Let's test a few more queries

# %% [markdown]
# ### Query 2

# %%
# Test with metadata filtering - should focus specifically on cookbook reviews
run_unstructured_kb_query("What do customers think about cookbook quality and recipe clarity?", use_metadata_filtering=True)
# Out:
# ==================== RETRIEVE AND GENERATE API WITH METADATA FILTERING ====================
#
# QUERY: What do customers think about cookbook quality and recipe clarity?
# ----------------------------------------
# GENERATED RESPONSE:
# ----------------------------------------
# Customers are highly positive about recipe clarity in this cookbook. Multiple reviewers praise the clear, step-by-step instructions that make even complex dishes feel manageable for home cooks of various skill levels. The instructions are consistently described as easy to follow and well-organized, with many customers noting that the breakdown of techniques helps demystify complicated cooking methods. Regarding overall cookbook quality, reviews are mostly positive but with some reservations. The majority of customers praise the beautiful step-by-step photography and visual presentation as a significant strength. However, opinions on recipe selection and execution are mixed—while enthusiastic reviewers report high success rates with their cooking attempts and appreciate the diverse recipe collection, others felt the collection was uneven, with some recipes being overly complicated or requiring hard-to-find specialty ingredients. Recipe success rates vary among reviewers, from "home runs" across the board to roughly 75% success rates, suggesting that results may depend on individual cooking experience and preferences. Customers particularly appreciate the cookbook's helpful additions, including ingredient substitution suggestions and basic cooking technique sections. These features enhance the overall value and accessibility for home cooks looking to expand their culinary skills.
#
# CITATIONS (3 found):
# ----------------------------------------
#
# Citation 1:
#   Reference 1:
#     Content: I absolutely love this cookbook - the recipes are incredibly diverse and each one I've tried has been a home run with my family! The instructions are crystal clear, with gorgeous step-by-step photos t...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_8155
#       review_id: review_8155
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_280
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-06-19
#       review_text: I absolutely love this cookbook - the recipes are incredibly diverse and each one I've tried has been a home run with my family! The instructions are crystal clear, with gorgeous step-by-step photos that make even complicated dishes feel approachable, and I especially appreciate how the author includes helpful tips and ingredient substitution suggestions for each recipe. From weeknight dinner solutions to impressive dishes for entertaining, this cookbook has quickly become my go-to resource in the kitchen, and I've already recommended it to several of my foodie friends.
#       customer_id: customer_1954
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ARaJD5JwBGTaWacUHVqv2
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_8155
#   Reference 2:
#     Content: I absolutely love this cookbook - the recipes are not only delicious but also incredibly approachable for home cooks of all skill levels. The author does an amazing job of breaking down complex techni...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_7445
#       review_id: review_7445
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_280
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2022-11-16
#       review_text: I absolutely love this cookbook - the recipes are not only delicious but also incredibly approachable for home cooks of all skill levels. The author does an amazing job of breaking down complex techniques into easy-to-follow steps, and I've already successfully made several dishes that have seriously impressed my family and friends. From the beautiful photography to the thoughtful ingredient substitution suggestions, this cookbook has quickly become my go-to resource in the kitchen, and I can't recommend it highly enough.
#       customer_id: customer_1556
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ATaJD5JwBGTaWacUHXKtD
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_7445
#   Reference 3:
#     Content: I absolutely love this cookbook - the recipes are approachable yet creative, and I've already tried at least a dozen different dishes that have become instant favorites in my kitchen. The author does ...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_1802
#       review_id: review_1802
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_280
#       rating: 4.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-11-13
#       review_text: I absolutely love this cookbook - the recipes are approachable yet creative, and I've already tried at least a dozen different dishes that have become instant favorites in my kitchen. The author does an amazing job of providing clear, step-by-step instructions that even a home cook with moderate skills can follow, and the beautiful photography makes each recipe look so appetizing. While not every single recipe has been a home run for me, at least 75% of what I've made has been delicious, and I appreciate how the book offers a great mix of weeknight dinner options and more sophisticated meals for entertaining. Definitely a worthwhile addition to any home cook's cookbook collection!
#       customer_id: customer_2884
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3A_oxD5JwB12yEb9RmVwyQ
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_1802
#
# Citation 2:
#   Reference 1:
#     Content: I absolutely love this cookbook - the recipes are incredibly diverse and each one I've tried has been a home run with my family! The instructions are crystal clear, with gorgeous step-by-step photos t...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_8155
#       review_id: review_8155
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_280
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-06-19
#       review_text: I absolutely love this cookbook - the recipes are incredibly diverse and each one I've tried has been a home run with my family! The instructions are crystal clear, with gorgeous step-by-step photos that make even complicated dishes feel approachable, and I especially appreciate how the author includes helpful tips and ingredient substitution suggestions for each recipe. From weeknight dinner solutions to impressive dishes for entertaining, this cookbook has quickly become my go-to resource in the kitchen, and I've already recommended it to several of my foodie friends.
#       customer_id: customer_1954
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ARaJD5JwBGTaWacUHVqv2
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_8155
#   Reference 2:
#     Content: I bought this cookbook hoping for some fresh recipe ideas, but it's just okay. While a few recipes looked promising, many seemed overly complicated or required specialty ingredients that aren't easy t...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_1566
#       review_id: review_1566
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_842
#       rating: 3.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-07-17
#       review_text: I bought this cookbook hoping for some fresh recipe ideas, but it's just okay. While a few recipes looked promising, many seemed overly complicated or required specialty ingredients that aren't easy to find. The photography is nice and the instructions are clear, but I found myself only wanting to try 3-4 recipes out of the entire collection. If you're an experienced home cook looking for something unique, this might be worth checking out, but beginners might find it a bit challenging.
#       customer_id: customer_2951
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3A-oxD5JwB12yEb9RmSwzE
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_1566
#   Reference 3:
#     Content: I absolutely love this cookbook - the recipes are not only delicious but also incredibly approachable for home cooks of all skill levels. The author does an amazing job of breaking down complex techni...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_7445
#       review_id: review_7445
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_280
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2022-11-16
#       review_text: I absolutely love this cookbook - the recipes are not only delicious but also incredibly approachable for home cooks of all skill levels. The author does an amazing job of breaking down complex techniques into easy-to-follow steps, and I've already successfully made several dishes that have seriously impressed my family and friends. From the beautiful photography to the thoughtful ingredient substitution suggestions, this cookbook has quickly become my go-to resource in the kitchen, and I can't recommend it highly enough.
#       customer_id: customer_1556
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ATaJD5JwBGTaWacUHXKtD
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_7445
#   Reference 4:
#     Content: I picked up this cookbook hoping for some fresh recipe ideas, and while there were a few interesting dishes, the overall collection felt a bit uneven. The instructions were clear enough, but some reci...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_4864
#       review_id: review_4864
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_842
#       rating: 3.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2022-10-20
#       review_text: I picked up this cookbook hoping for some fresh recipe ideas, and while there were a few interesting dishes, the overall collection felt a bit uneven. The instructions were clear enough, but some recipes seemed overly complicated for home cooking, and not all of them turned out as well as I expected when I tried them in my kitchen. I appreciated the nice color photographs and the section on basic cooking techniques, but I'm not sure I'll be reaching for this book as often as some of my other cookbooks.
#       customer_id: customer_1831
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3AB4xD5JwB12yEb9RmWw1M
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_4864
#   Reference 5:
#     Content: I absolutely love this cookbook - the recipes are approachable yet creative, and I've already tried at least a dozen different dishes that have become instant favorites in my kitchen. The author does ...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_1802
#       review_id: review_1802
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_280
#       rating: 4.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-11-13
#       review_text: I absolutely love this cookbook - the recipes are approachable yet creative, and I've already tried at least a dozen different dishes that have become instant favorites in my kitchen. The author does an amazing job of providing clear, step-by-step instructions that even a home cook with moderate skills can follow, and the beautiful photography makes each recipe look so appetizing. While not every single recipe has been a home run for me, at least 75% of what I've made has been delicious, and I appreciate how the book offers a great mix of weeknight dinner options and more sophisticated meals for entertaining. Definitely a worthwhile addition to any home cook's cookbook collection!
#       customer_id: customer_2884
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3A_oxD5JwB12yEb9RmVwyQ
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_1802
#
# Citation 3:
#   Reference 1:
#     Content: I absolutely love this cookbook - the recipes are incredibly diverse and each one I've tried has been a home run with my family! The instructions are crystal clear, with gorgeous step-by-step photos t...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_8155
#       review_id: review_8155
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_280
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2021-06-19
#       review_text: I absolutely love this cookbook - the recipes are incredibly diverse and each one I've tried has been a home run with my family! The instructions are crystal clear, with gorgeous step-by-step photos that make even complicated dishes feel approachable, and I especially appreciate how the author includes helpful tips and ingredient substitution suggestions for each recipe. From weeknight dinner solutions to impressive dishes for entertaining, this cookbook has quickly become my go-to resource in the kitchen, and I've already recommended it to several of my foodie friends.
#       customer_id: customer_1954
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ARaJD5JwBGTaWacUHVqv2
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_8155
#   Reference 2:
#     Content: I absolutely love this cookbook - the recipes are not only delicious but also incredibly approachable for home cooks of all skill levels. The author does an amazing job of breaking down complex techni...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_7445
#       review_id: review_7445
#       product_type: cookbook
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_280
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2022-11-16
#       review_text: I absolutely love this cookbook - the recipes are not only delicious but also incredibly approachable for home cooks of all skill levels. The author does an amazing job of breaking down complex techniques into easy-to-follow steps, and I've already successfully made several dishes that have seriously impressed my family and friends. From the beautiful photography to the thoughtful ingredient substitution suggestions, this cookbook has quickly become my go-to resource in the kitchen, and I can't recommend it highly enough.
#       customer_id: customer_1556
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3ATaJD5JwBGTaWacUHXKtD
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_7445

# %% [markdown]
# ### Query 3

# %%
# Test with metadata filtering - should focus on high-rated furniture reviews
run_unstructured_kb_query("What features make customers give 5-star ratings to furniture products?", use_metadata_filtering=True)
# Out:
# ==================== RETRIEVE AND GENERATE API WITH METADATA FILTERING ====================
#
# QUERY: What features make customers give 5-star ratings to furniture products?
# ----------------------------------------
# GENERATED RESPONSE:
# ----------------------------------------
# Based on customer feedback, several key features contribute to 5-star furniture ratings. Quality construction and durability are essential, with customers appreciating materials that withstand regular use without deterioration. Comfort is equally important, particularly in seating furniture where cushions that maintain their shape and soft, pleasant fabrics enhance the overall experience.
#
# Design aesthetics also play a significant role, with modern, stylish appearances that complement home décor and earn compliments from visitors being highly valued. Practical benefits matter too, including easy assembly that doesn't require extensive time or effort. Finally, the overall value proposition—delivering a product that exceeds expectations and represents a worthwhile investment—drives customers to give top ratings and recommend the furniture to others.
#
# CITATIONS (1 found):
# ----------------------------------------
#
# Citation 1:
#   Reference 1:
#     Content: I absolutely love my new sectional sofa from this brand - the quality is outstanding and it fits perfectly in my living room! The fabric is incredibly soft and durable, and the cushions maintain their...
#     Metadata:
#       x-amz-bedrock-kb-source-uri: s3://product-reviews-unstructured-onamusic-bucket/review_1262
#       review_id: review_1262
#       product_type: furniture
#       x-amz-bedrock-kb-data-source-id: 5JXJKPTBRI
#       product_id: product_561
#       rating: 5.0
#       x-amz-bedrock-kb-source-file-modality: TEXT
#       created_at: 2022-03-29
#       review_text: I absolutely love my new sectional sofa from this brand - the quality is outstanding and it fits perfectly in my living room! The fabric is incredibly soft and durable, and the cushions maintain their shape even after weeks of daily use. Assembly was surprisingly easy, and the modern design has received tons of compliments from my friends and family. This is hands down the best furniture purchase I've made in years, and I would recommend it to anyone looking for a stylish and comfortable seating solution.
#       customer_id: customer_2108
#       x-amz-bedrock-kb-chunk-id: 1%3A0%3AVKJD5JwBGTaWacUHXqtM
#     Source: s3://product-reviews-unstructured-onamusic-bucket/review_1262

# %% [markdown]
# ## Next Steps
#
# If all tests completed successfully, your unstructured Knowledge Base is working correctly with both basic retrieval and advanced metadata filtering!
#
# **Ready to continue?** Proceed to [**Lab 2**](../Lab%202%20-%20Structured%20KB/2.1-prerequisites-structured-kb.ipynb) to create a structured Knowledge Base that connects to Amazon Redshift for querying transactional data.
